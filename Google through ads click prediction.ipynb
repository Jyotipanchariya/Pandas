# %%
import pandas as pd

# %%
df= pd.DataFrame()

# %%
df= pd.read_csv("C:\\Users\\jyoti\\OneDrive\\Desktop\\New folder\\titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# # EDA

# %%
# EDA==> Exploratory Data Analysis

# %% [markdown]
# # Parts of EDA
# 1. Univariate Analysis ==> Analysis on a single independent column
# 2. Bivariate Analysis==> Analysis on two column
# 3. Multivariate Analysis==> Analysis on more than 2 columns

# %%
#Data types 
# 1. Numerical data==  continuous data ==> age(year,month , days),height , weight etc...
# 2. Categorial Data ==> Descrete DATA ==> total number of employees

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt # visualization library

import seaborn as sns # matplotlib's updated

# %% [markdown]
# # 1. Univariate Analysis

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.countplot(x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# if we want to see actual values than we use value_counts()

df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
# if we want to check for pclass then

sns.countplot(x=df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
#if we want to find out percentage then use piechart
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='pie',autopct= '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
#if we have numeriacl data than we use histogram 
#because it finds the distribution

# %%
plt.hist(df['Age'])
# Out:
# (array([16., 16., 71., 97., 43., 37., 25., 17.,  9.,  1.]),
#  array([ 0.17 ,  7.753, 15.336, 22.919, 30.502, 38.085, 45.668, 53.251,
#         60.834, 68.417, 76.   ]),
#  <BarContainer object of 10 artists>)

# %%
# 2. DISTRIBUTION PLOT==> 
#curve ==> KDE (kernal density extraction)
#use for find probablity

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\jyoti\AppData\Local\Temp\ipykernel_23536\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age']  , hist=False) # histrogram remove
# Out:
# C:\Users\jyoti\AppData\Local\Temp\ipykernel_23536\583397462.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age']  , hist=False) # histrogram remove
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# 3. Boxplot

# for find our outliers
# 1. lower fence
# 2. 25% data
# 3.IQR(Inter Quartile Range)(75%-25%)
# 4. 75% data
# 5. upper fence

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
import pandas as pd

# %%
# df= pd.DataFrame(/)

# %%
df= pd.read_csv("C:\\Users\\jyoti\\OneDrive\\Desktop\\New folder\\tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Bivariate Analysis

# %%
# 1 scatterplot (Numerical column - Numerical column )

# %%
import matplotlib.pyplot as plt # visualization library

import seaborn as sns

# %%
sns.scatterplot(x =df['total_bill'],
                y = df['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill" ,y= "tip",  data=df,hue= df['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill" ,
               y= "tip" , data = df,
               hue = df['sex'], style = df['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#BAR PLOT (numeric column)

# %%
df2= pd.read_csv("C:\\Users\\jyoti\\OneDrive\\Desktop\\New folder\\titanic.csv")

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
sns.barplot(x= df2['Pclass'] , y= df2['Age']) # titanic data
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot( x=df2['Pclass'] ,  y=df2['Age'], hue=df2['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.distplot(df2[df2['Survived']==0]['Age'] , hist=False)
# Out:
# C:\Users\jyoti\AppData\Local\Temp\ipykernel_12104\939938066.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2[df2['Survived']==0]['Age'] , hist=False)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
#HeatMap (Categoraical - Categoraical)
p= pd.crosstab(df2['Pclass'], df2['Survived'])
p
# Out:
# Survived    0   1
# Pclass
# 1          57  50
# 2          63  30
# 3         146  72

# %%
sns.heatmap(p)
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
# df2.groupby('Pclass').mean()

# %%
df2 = df2[['Survived' , 'Pclass' , 'Age' , 'Fare']]

# %%
df2 = df2.dropna()

# %%
((df2.groupby('Pclass').mean()['Survived'])*100).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
sns.pairplot(df2)
# Out:
# C:\Users\jyoti\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
